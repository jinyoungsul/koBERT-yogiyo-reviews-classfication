# %% [markdown]
# ## Colab KorBERT Intention Classification WEB 구동

# %% [markdown]
# 시작전에 server.py, run_intent_classify.py, settings.py requirements_colab.txt, templates, static 폴더와 파일을 각자의 드라이브에 업로드 해주세요.
#
# (bert finetuning에 사용했던 폴더들이 있는 경로에 업로드 해주시면 됩니다.)

# %%
# 드라이브 마운트
import os
from google.colab import drive
drive.mount("/content/drive")

path = '/content/drive/MyDrive/bert_classification_kor/eojeol' # 개인 및 팀에 맞게 바꿔주세요
os.chdir(path)
# Out:
# Mounted at /content/drive

# %%
# 깔려있는 tensorflow 삭제
# !pip uninstall tensorflow -y
# Out:
# Found existing installation: tensorflow 2.6.0
# Uninstalling tensorflow-2.6.0:
#   Successfully uninstalled tensorflow-2.6.0

# %%
# 필요한 모듈 설치
# !pip install -r requirements_colab.txt
# Out:
# ...
#      |████████████████████████████████| 94 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 411.5 MB 7.9 kB/s
# ...
#      |████████████████████████████████| 89 kB 9.9 MB/s
# ...
#      |████████████████████████████████| 19.4 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 58.0 MB/s
# ...
#      |████████████████████████████████| 503 kB 70.6 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 55.5 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 86 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 448 kB 66.4 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=87d946fc1f05f3b4b18b352abf08e5dd6f3b7110d3ab9bb324b66cf26e3362f8
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
# ...

# %%
# 실행
# !python server.py
# Out:
#  * Serving Flask app "server" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://77762e6e7e1b.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [19/Aug/2021 06:41:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Aug/2021 06:41:53] "GET /static/script.js HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Aug/2021 06:41:53] "GET /static/css/main.css HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Aug/2021 06:41:54] "GET /static/salad1.png HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Aug/2021 06:41:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Aug/2021 06:41:56] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [19/Aug/2021 06:41:56] "GET /static/css/main.css HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Aug/2021 06:41:56] "GET /static/script.js HTTP/1.1" 200 -
# ...
