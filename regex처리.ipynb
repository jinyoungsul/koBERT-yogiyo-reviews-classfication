# %%
import pandas as pd
import glob
import re

# %%
file_list = glob.glob('data/*.csv')
print(file_list)
# Out:
# ['data\\노랑통닭-운정1호점.csv', 'data\\치킨파티-운정점.csv', 'data\\피자이탈리-운정점.csv']

# %%
for ind,file in enumerate(file_list):
    if ind == 0:
        yogiyo_review = pd.read_csv(file)
    else:
        yogiyo_review = pd.concat([yogiyo_review, pd.read_csv(file)])
yogiyo_review_df = yogiyo_review.copy()

# %%
yogiyo_review.head()
# Out:
#    Unnamed: 0 Category Location  Restaurant UserID  \
# 0           0       치킨     운정1동  노랑통닭-운정1호점  ta**님
# 1           1       치킨     운정1동  노랑통닭-운정1호점  hs**님
# 2           2       치킨     운정1동  노랑통닭-운정1호점  ka**님
# 3           3       치킨     운정1동  노랑통닭-운정1호점  dd**님
# 4           4       치킨     운정1동  노랑통닭-운정1호점  ms**님
#
#                                                 Menu  \
# 0         엄청큰 후라이드치킨/1,똥집감자튀김/1(추가 선택(콜라 1.25L로 변경))
# 1                              순살 3종세트（후라이드＋양념＋깐풍）/1
# 2    알싸한 마늘치킨/1(사이즈 선택(Size Up),추가 선택(콜라 1.25L로 변경))
# 3  알싸한 마늘치킨/1(사이즈 선택(Size Up),사이드 메뉴(즉석 치즈 떡볶이,노랑...
# 4    알싸한 마늘치킨/1(사이즈 선택(Regular),추가 선택(콜라 1.25L로 변경))
#
#                                               Review    Date  Total  Taste  \
# 0                       다른 지점에 비해 여긴 넘바삭하그 맛잇음요 똥집쵝오  10시간 전      5    5.0
# 1                                        10자 제한 끄적끄적      어제      5    5.0
# 2                                        맛있네요 마늘치킨 굳    3일 전      5    5.0
# 3  중복때 너무 바쁘셔서 예상시간보다 배달이 많이 늦어졌지만 그래도 맛있게 해주셔서 잘...    3일 전      5    5.0
# 4                       배달도빠르고 양도맛고 따뜻하고 바삭하게 잘받았어요~    4일 전      5    5.0
#
#    Quantity  Delivery
# 0       5.0       5.0
# 1       5.0       5.0
# 2       5.0       5.0
# 3       5.0       5.0
# 4       5.0       5.0

# %%
yogiyo_review_df = yogiyo_review_df.drop(['Unnamed: 0','Category','Location','Restaurant','UserID','Menu','Date','Taste','Quantity','Delivery'],axis=1)
yogiyo_review_df
# Out:
#                                                  Review  Total
# 0                          다른 지점에 비해 여긴 넘바삭하그 맛잇음요 똥집쵝오      5
# 1                                           10자 제한 끄적끄적      5
# 2                                           맛있네요 마늘치킨 굳      5
# 3     중복때 너무 바쁘셔서 예상시간보다 배달이 많이 늦어졌지만 그래도 맛있게 해주셔서 잘...      5
# 4                          배달도빠르고 양도맛고 따뜻하고 바삭하게 잘받았어요~      5
# ...                                                 ...    ...
# 1968  피자 토핑많고 맛괜찮네요 골드크러스트 추가했는데 생각했던게 아니라서좀 실망 담엔 그...      5
# 1969  와 정말 맛있어요 최근 먹은 피자중에 단연 최고에요 최고 최고 !! 가게 번창하세요...      5
# 1970  여기가 피자 맛집이었네요 ㅋㅋㅋ 너무 맛있어요^^ 도우끝까지 토핑이 되어 있어서 버...      5
# 1971  진짜 맛있어요 원래 리뷰 안쓰는데, 쓸만큼 맛있음... 솔직히 피자러버라 여기저기 ...      5
# 1972  진짜 맛있어요ㅠ 리뷰이벤트로 라지로 왔는데 빵 끝부분까지 토핑 되어있어서 완전 좋아...      5
#
# [3822 rows x 2 columns]

# %%
yogiyo_review_df.Total.value_counts()
# Out:
# 5    3103
# 4     456
# 3     147
# 1      69
# 2      47
# Name: Total, dtype: int64

# %%
# 특수문자를 공백으로 바꿔주는 함수
def regex_review(review):
    p = re.compile('(\W|[ㅠㅋㅎㅜ]|[0-9])')
    result = p.sub(' ',review)
    return result
yogiyo_review_df['regex_review'] = yogiyo_review_df['Review'].apply(regex_review)
yogiyo_review_df
# Out:
# <ipython-input-11-154bff7fa070>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yogiyo_review_df['regex_review'] = yogiyo_review_df['Review'].apply(regex_review)
#                                                  Review  Total  \
# 3     중복때 너무 바쁘셔서 예상시간보다 배달이 많이 늦어졌지만 그래도 맛있게 해주셔서 잘...      5
# 7     역시 노랑통닭 알싸~~한 마늘치킨 맛있어요! 리뷰이벤트 적었는데 서비스 안주셨더라구...      5
# 9     참시켜봐서 이렇게 구분이 안될정도로 잘게 튀겨져 나오는줄 몰랐어요 깐풍가맛있는데 모...      3
# 20    처음 시켜 먹었는데 맛있어요. 후라이드는 바삭바삽하고 양녕과 깐풍은 따뜻하게 와서 ...      5
# 34    치킨이 뜨거웠음 좋았겠지만 식었어도 바삭하니 괜찮았어여.. 소스도 소금, 양념치킨용...      5
# ...                                                 ...    ...
# 1968  피자 토핑많고 맛괜찮네요 골드크러스트 추가했는데 생각했던게 아니라서좀 실망 담엔 그...      5
# 1969  와 정말 맛있어요 최근 먹은 피자중에 단연 최고에요 최고 최고 !! 가게 번창하세요...      5
# 1970  여기가 피자 맛집이었네요 ㅋㅋㅋ 너무 맛있어요^^ 도우끝까지 토핑이 되어 있어서 버...      5
# 1971  진짜 맛있어요 원래 리뷰 안쓰는데, 쓸만큼 맛있음... 솔직히 피자러버라 여기저기 ...      5
# 1972  진짜 맛있어요ㅠ 리뷰이벤트로 라지로 왔는데 빵 끝부분까지 토핑 되어있어서 완전 좋아...      5
#
#                                            regex_review  길이
# 3     중복때 너무 바쁘셔서 예상시간보다 배달이 많이 늦어졌지만 그래도 맛있게 해주셔서 잘...  18
# 7     역시 노랑통닭 알싸  한 마늘치킨 맛있어요  리뷰이벤트 적었는데 서비스 안주셨더라구...  31
# 9     참시켜봐서 이렇게 구분이 안될정도로 잘게 튀겨져 나오는줄 몰랐어요 깐풍가맛있는데 모...  17
# 20    처음 시켜 먹었는데 맛있어요  후라이드는 바삭바삽하고 양녕과 깐풍은 따뜻하게 와서 ...  17
# 34    치킨이 뜨거웠음 좋았겠지만 식었어도 바삭하니 괜찮았어여   소스도 소금  양념치킨용...  25
# ...                                                 ...  ..
# 1968  피자 토핑많고 맛괜찮네요 골드크러스트 추가했는데 생각했던게 아니라서좀 실망 담엔 그...  13
# 1969  와 정말 맛있어요 최근 먹은 피자중에 단연 최고에요 최고 최고    가게 번창하세요...  12
# 1970  여기가 피자 맛집이었네요     너무 맛있어요   도우끝까지 토핑이 되어 있어서 버...  28
# 1971  진짜 맛있어요 원래 리뷰 안쓰는데  쓸만큼 맛있음    솔직히 피자러버라 여기저기 ...  51
# 1972  진짜 맛있어요  리뷰이벤트로 라지로 왔는데 빵 끝부분까지 토핑 되어있어서 완전 좋아...  16
#
# [966 rows x 4 columns]

# %%
yogiyo_review_df['길이'] = [len(regex_review.split()) for regex_review in yogiyo_review_df.regex_review.to_list()]

# %%
yogiyo_review_df = yogiyo_review_df[yogiyo_review_df['길이'] >= 12]

# %%
yogiyo_review_df[['Total','regex_review']].to_csv('data/data.txt',sep='\t')
